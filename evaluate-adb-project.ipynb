# %% [markdown]
# # ADB Phase 2 Project Evaluation Notebook

# %% [markdown]
# **Purpose**: This notebook evaluates the performance of a semantic search project by analyzing databases of various sizes.
#
# ### Evaluation Focus:
# - **Database Sizes**:
#   - 1 Million Records
#   - 10 Million Records
#   - 15 Million Records
#   - 20 Million Records
#
# For each database size, this notebook will:
# - Generate random vectors for the database.
# - Use the `VecDB` class (implemented by students) to retrieve queries
# - Evaluate and report retrieval time, accuracy, and RAM usage.
#
# ### Project Constraints:
# Refer to the project document for details on RAM, Disk, Time, and Score constraints.
#
# ### Notebook Structure:
# 1. **Part 1 - Modifiable Cells**:
#    - Includes cells that teams are allowed to modify, specifically for these variables only:
#      - GitHub repository link (including PAT token).
#      - Google Drive IDs for indexes files.
#      - Paths for loading existing indexes.
#
# 2. **Part 2 - Non-Modifiable Cells**:
#    - Contains essential setup and evaluation code that must not be modified.
#    - Students should only modify inputs in Part 1 to ensure smooth execution of the notebook.

# %% [markdown]
# ## Part 1 - Modifiable Cells

# %% [markdown]
# Each team must provide a unique GitHub repository link that includes a PAT token. This link will allow the notebook to download the necessary code for evaluation.

# %%
# !git clone https://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@github.com/mou-code/vec_db.git
# Out:
# Cloning into 'vec_db'...
# remote: Enumerating objects: 389, done.
# remote: Counting objects: 100% (197/197), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 389 (delta 123), reused 153 (delta 95), pack-reused 192 (from 1)
# Receiving objects: 100% (389/389), 4.34 MiB | 14.53 MiB/s, done.
# Resolving deltas: 100% (223/223), done.

# %% [markdown]
# # Database Path Instructions

# %% [markdown]
# Teams need to specify paths for each database (1M, 10M, 15M, 20M records) as follows:
#
# 1. Zip each database directory/file after generation.
# 2. Upload the zip file to Google Drive.
# 3. Share the file with "Anyone with the link."
# 4. Extract the file ID from the link (e.g., for `https://drive.google.com/file/d/1j1gAU3kvdRqcOoKI5K5FgMMUZpOQANah/view`, the ID is `1j1gAU3kvdRqcOoKI5K5FgMMUZpOQANah`).
# 5. Assign each ID to the appropriate variable in Part 1.
# 6. Provide the local PATH for each database to be passed to the initializer for automatic loading of the database and index (to be submitted during the project final phase).
#
# **Note**: The code will download and unzip these files automatically. Once extracted, the local path for each database should be specified to enable the notebook to load databases and indexes.

# %%
TEAM_NUMBER = 14
GDRIVE_ID_DB_1M = "1bRyKa-Wv8rfu62opI28iFMnMkn02QYdA"
GDRIVE_ID_DB_10M = "1gPQpPzw0LKFH4ysnbtOpA-59PZu9Sjq0"
GDRIVE_ID_DB_15M = "1vO8vCeAE6wcK0Lyig9JdI1H97Kxl2GDN"
GDRIVE_ID_DB_20M = "1-d9bvnG4Z3ddtX0omURwleeRreewk9I9"
PATH_DB_1M = "saved_db_1m.csv"
PATH_DB_10M = "saved_db_10m.csv"
PATH_DB_15M = "saved_db_15m.csv"
PATH_DB_20M = "saved_db_20m.csv"

# %% [markdown]
# **Query Seed Number**:
# This number will be adjusted during discussions by the instructor.

# %%
QUERY_SEED_NUMBER = 10

# %% [markdown]
# **Final Submission Checklist**:
# Ensure the following items are included in your final submission:
# - `TEAM_NUMBER`
# - GitHub clone link (with PAT token)
# - Google Drive IDs for each database:
#   - `GDRIVE_ID_DB_1M`, `GDRIVE_ID_DB_10M`, `GDRIVE_ID_DB_15M`, `GDRIVE_ID_DB_20M`
# - Paths for each database:
#   - `PATH_DB_1M`, `PATH_DB_10M`, `PATH_DB_15M`, `PATH_DB_20M`
# - Project document detailing the work and findings.

# %% [markdown]
# ## Part 2: Do Not Modify Beyond This Point
# ### Note:
# This section contains setup and evaluation code that should not be edited by students. Only the instructor may modify this section in case of a major bug.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %cd vec_db
# Out:
# /kaggle/working/vec_db

# %% [markdown]
# This cell to run any additional requirement that your code need <br>

# %%
# !conda install -y gdown  &> log.txt

# %%
# !pip install memory-profiler &> log.txt
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: memory-profiler in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.61.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from memory-profiler->-r requirements.txt (line 2)) (5.9.3)

# %% [markdown]
# This cell to download the zip files and unzip them here.

# %%
# !gdown $GDRIVE_ID_DB_1M -O saved_db_1m.zip
# !gdown $GDRIVE_ID_DB_10M -O saved_db_10m.zip
# !gdown $GDRIVE_ID_DB_15M -O saved_db_15m.zip
# !gdown $GDRIVE_ID_DB_20M -O saved_db_20m.zip
# !unzip saved_db_1m.zip
# !unzip saved_db_10m.zip
# !unzip saved_db_15m.zip
# !unzip saved_db_20m.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bRyKa-Wv8rfu62opI28iFMnMkn02QYdA
# To: /kaggle/working/vec_db/saved_db_1m.zip
# 100%|██████████████████████████████████████| 7.32M/7.32M [00:00<00:00, 17.6MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1gPQpPzw0LKFH4ysnbtOpA-59PZu9Sjq0
# From (redirected): https://drive.google.com/uc?id=1gPQpPzw0LKFH4ysnbtOpA-59PZu9Sjq0&confirm=t&uuid=beaea3cb-91c7-4acb-8950-d14461175311
# To: /kaggle/working/vec_db/saved_db_10m.zip
# 100%|███████████████████████████████████████| 60.3M/60.3M [00:00<00:00, 176MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1vO8vCeAE6wcK0Lyig9JdI1H97Kxl2GDN
# From (redirected): https://drive.google.com/uc?id=1vO8vCeAE6wcK0Lyig9JdI1H97Kxl2GDN&confirm=t&uuid=9a9be21b-3e42-484e-a359-43b700c9ff27
# To: /kaggle/working/vec_db/saved_db_15m.zip
# 100%|█████████████████████████████████████████| 105M/105M [00:00<00:00, 207MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1-d9bvnG4Z3ddtX0omURwleeRreewk9I9
# From (redirected): https://drive.google.com/uc?id=1-d9bvnG4Z3ddtX0omURwleeRreewk9I9&confirm=t&uuid=8560ca06-b546-4845-868d-85012ca1b21d
# To: /kaggle/working/vec_db/saved_db_20m.zip
# 100%|████████████████████████████████████████| 136M/136M [00:05<00:00, 23.6MB/s]
# Archive:  saved_db_1m.zip
#   inflating: saved_db_1m/level1_centroids_saved_db_1m.csv
#    creating: saved_db_1m/second_level_centroids_saved_db_1m.csv/
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster0
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster1
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster10
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster100
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster101
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster102
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster103
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster104
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster105
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster106
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster107
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster108
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster109
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster11
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster110
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster111
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster112
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster113
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster114
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster115
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster116
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster117
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster118
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster119
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster12
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster120
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster121
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster122
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster123
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster124
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster125
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster126
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster127
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster128
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster129
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster13
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster130
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster131
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster132
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster133
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster134
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster135
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster136
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster137
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster138
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster139
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster14
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster140
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster141
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster142
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster143
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster144
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster145
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster146
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster147
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster148
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster149
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster15
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster150
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster151
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster152
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster153
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster154
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster155
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster156
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster157
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster158
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster159
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster16
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster160
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster161
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster162
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster163
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster164
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster165
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster166
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster167
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster168
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster169
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster17
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster170
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster171
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster172
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster173
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster174
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster175
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster176
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster177
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster178
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster179
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster18
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster180
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster181
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster182
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster183
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster184
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster185
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster186
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster187
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster188
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster189
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster19
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster190
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster191
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster192
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster193
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster194
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster195
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster196
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster197
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster198
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster199
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster2
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster20
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster200
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster201
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster202
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster203
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster204
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster205
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster206
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster207
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster208
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster209
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster21
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster210
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster211
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster212
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster213
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster214
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster215
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster216
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster217
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster218
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster219
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster22
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster220
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster221
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster222
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster223
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster224
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster225
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster226
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster227
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster228
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster229
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster23
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster230
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster231
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster232
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster233
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster234
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster235
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster236
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster237
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster238
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster239
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster24
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster240
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster241
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster242
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster243
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster244
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster245
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster246
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster247
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster248
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster249
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster25
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster250
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster251
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster252
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster253
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster254
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster255
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster26
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster27
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster28
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster29
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster3
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster30
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster31
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster32
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster33
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster34
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster35
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster36
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster37
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster38
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster39
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster4
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster40
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster41
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster42
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster43
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster44
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster45
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster46
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster47
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster48
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster49
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster5
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster50
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster51
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster52
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster53
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster54
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster55
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster56
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster57
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster58
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster59
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster6
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster60
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster61
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster62
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster63
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster64
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster65
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster66
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster67
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster68
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster69
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster7
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster70
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster71
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster72
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster73
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster74
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster75
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster76
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster77
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster78
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster79
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster8
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster80
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster81
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster82
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster83
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster84
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster85
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster86
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster87
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster88
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster89
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster9
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster90
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster91
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster92
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster93
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster94
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster95
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster96
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster97
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster98
#   inflating: saved_db_1m/second_level_centroids_saved_db_1m.csv/level2_centroids_cluster99
# Archive:  saved_db_10m.zip
#   inflating: saved_db_10m/level1_centroids_saved_db_10m.csv
#    creating: saved_db_10m/second_level_centroids_saved_db_10m.csv/
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster0
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster10
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster100
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1000
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1001
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1002
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1003
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1004
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1005
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1006
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1007
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1008
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1009
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster101
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1010
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1011
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1012
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1013
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1014
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1015
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1016
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1017
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1018
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1019
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster102
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1020
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1021
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1022
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1023
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1024
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1025
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1026
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1027
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1028
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1029
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster103
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1030
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1031
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1032
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1033
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1034
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1035
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1036
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1037
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1038
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1039
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster104
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1040
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1041
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1042
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1043
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1044
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1045
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1046
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1047
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1048
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1049
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster105
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1050
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1051
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1052
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1053
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1054
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1055
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1056
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1057
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1058
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1059
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster106
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1060
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1061
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1062
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1063
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1064
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1065
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1066
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1067
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1068
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1069
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster107
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1070
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1071
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1072
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1073
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1074
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1075
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1076
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1077
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1078
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1079
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster108
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1080
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1081
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1082
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1083
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1084
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1085
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1086
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1087
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1088
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1089
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster109
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1090
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1091
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1092
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1093
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1094
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1095
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1096
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1097
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1098
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1099
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster11
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster110
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1100
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1101
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1102
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1103
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1104
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1105
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1106
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1107
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1108
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1109
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster111
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1110
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1111
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1112
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1113
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1114
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1115
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1116
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1117
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1118
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1119
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster112
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1120
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1121
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1122
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1123
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1124
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1125
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1126
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1127
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1128
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1129
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster113
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1130
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1131
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1132
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1133
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1134
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1135
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1136
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1137
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1138
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1139
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster114
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1140
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1141
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1142
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1143
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1144
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1145
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1146
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1147
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1148
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1149
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster115
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1150
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1151
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1152
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1153
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1154
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1155
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1156
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1157
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1158
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1159
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster116
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1160
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1161
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1162
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1163
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1164
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1165
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1166
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1167
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1168
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1169
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster117
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1170
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1171
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1172
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1173
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1174
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1175
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1176
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1177
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1178
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1179
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster118
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1180
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1181
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1182
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1183
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1184
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1185
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1186
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1187
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1188
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1189
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster119
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1190
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1191
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1192
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1193
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1194
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1195
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1196
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1197
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1198
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1199
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster12
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster120
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1200
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1201
#  extracting: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1202
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1203
#   inflating: saved_db_10m/second_level_centroids_saved_db_10m.csv/level2_centroids_cluster1204
# ...
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster85
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster850
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster851
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster852
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster853
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster854
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster855
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster856
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster857
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster858
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster859
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster86
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster860
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster861
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster862
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster863
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster864
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster865
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster866
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster867
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster868
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster869
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster87
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster870
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster871
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster872
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster873
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster874
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster875
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster876
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster877
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster878
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster879
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster88
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster880
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster881
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster882
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster883
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster884
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster885
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster886
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster887
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster888
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster889
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster89
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster890
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster891
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster892
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster893
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster894
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster895
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster896
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster897
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster898
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster899
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster9
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster90
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster900
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster901
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster902
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster903
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster904
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster905
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster906
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster907
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster908
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster909
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster91
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster910
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster911
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster912
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster913
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster914
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster915
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster916
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster917
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster918
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster919
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster92
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster920
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster921
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster922
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster923
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster924
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster925
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster926
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster927
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster928
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster929
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster93
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster930
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster931
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster932
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster933
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster934
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster935
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster936
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster937
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster938
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster939
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster94
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster940
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster941
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster942
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster943
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster944
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster945
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster946
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster947
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster948
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster949
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster95
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster950
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster951
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster952
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster953
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster954
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster955
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster956
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster957
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster958
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster959
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster96
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster960
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster961
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster962
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster963
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster964
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster965
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster966
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster967
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster968
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster969
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster97
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster970
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster971
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster972
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster973
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster974
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster975
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster976
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster977
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster978
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster979
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster98
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster980
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster981
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster982
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster983
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster984
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster985
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster986
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster987
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster988
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster989
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster99
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster990
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster991
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster992
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster993
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster994
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster995
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster996
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster997
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster998
#   inflating: saved_db_20m/second_level_centroids_saved_db_20m.csv/level2_centroids_cluster999

# %% [markdown]
# These are the functions for running and reporting

# %%
import numpy as np
DB_SEED_NUMBER = 42
ELEMENT_SIZE = np.dtype(np.float32).itemsize
DIMENSION = 70

# %%
import numpy as np
import os
from vec_db import VecDB
import time
from dataclasses import dataclass
from typing import List
from memory_profiler import memory_usage
import gc

@dataclass
class Result:
    run_time: float
    top_k: int
    db_ids: List[int]
    actual_ids: List[int]

def run_queries(db, queries, top_k, actual_ids, num_runs):
    """
    Run queries on the database and record results for each query.

    Parameters:
    - db: Database instance to run queries on.
    - queries: List of query vectors.
    - top_k: Number of top results to retrieve.
    - actual_ids: List of actual results to evaluate accuracy.
    - num_runs: Number of query executions to perform for testing.

    Returns:
    - List of Result
    """
    global results
    results = []
    for i in range(num_runs):
        tic = time.time()
        db_ids = db.retrieve(queries[i], top_k)
        toc = time.time()
        run_time = toc - tic
        results.append(Result(run_time, top_k, db_ids, actual_ids[i]))
    return results

def memory_usage_run_queries(args):
    """
    Run queries and measure memory usage during the execution.

    Parameters:
    - args: Arguments to be passed to the run_queries function.

    Returns:
    - results: The results of the run_queries.
    - memory_diff: The difference in memory usage before and after running the queries.
    """
    global results
    mem_before = max(memory_usage())
    mem = memory_usage(proc=(run_queries, args, {}), interval = 1e-3)
    return results, max(mem) - mem_before

def evaluate_result(results: List[Result]):
    """
    Evaluate the results based on accuracy and runtime.
    Scores are negative. So getting 0 is the best score.

    Parameters:
    - results: A list of Result objects

    Returns:
    - avg_score: The average score across all queries.
    - avg_runtime: The average runtime for all queries.
    """
    scores = []
    run_time = []
    for res in results:
        run_time.append(res.run_time)
        # case for retireving number not equal to top_k, socre will be the lowest
        if len(set(res.db_ids)) != res.top_k or len(res.db_ids) != res.top_k:
            scores.append( -1 * len(res.actual_ids) * res.top_k)
            continue
        score = 0
        for id in res.db_ids:
            try:
                ind = res.actual_ids.index(id)
                if ind > res.top_k * 3:
                    score -= ind
            except:
                score -= len(res.actual_ids)
        scores.append(score)

    return sum(scores) / len(scores), sum(run_time) / len(run_time)

def get_actual_ids_first_k(actual_sorted_ids, k):
    """
    Retrieve the IDs from the sorted list of actual IDs.
    actual IDs has the top_k for the 20 M database but for other databases we have to remove the numbers higher than the max size of the DB.

    Parameters:
    - actual_sorted_ids: A list of lists containing the sorted actual IDs for each query.
    - k: The DB size.

    Returns:
    - List of lists containing the actual IDs for each query for this DB.
    """
    return [[id for id in actual_sorted_ids_one_q if id < k] for actual_sorted_ids_one_q in actual_sorted_ids]

# %% [markdown]
# This code to generate all the files for databases.

# %%
def _write_vectors_to_file(vectors: np.ndarray, db_path) -> None:
    mmap_vectors = np.memmap(db_path, dtype=np.float32, mode='w+', shape=vectors.shape)
    mmap_vectors[:] = vectors[:]
    mmap_vectors.flush()

def generate_database(size: int) -> None:
    rng = np.random.default_rng(DB_SEED_NUMBER)
    vectors = rng.random((size, DIMENSION), dtype=np.float32)
    return vectors

vectors = generate_database(20*10**6)

db_filename_size_20M = 'saved_db_20M.dat'
if not os.path.exists(db_filename_size_20M): _write_vectors_to_file(vectors, db_filename_size_20M)
db_filename_size_15M = 'saved_db_15M.dat'
if not os.path.exists(db_filename_size_15M): _write_vectors_to_file(vectors[:15*10**6], db_filename_size_15M)
db_filename_size_10M = 'saved_db_10M.dat'
if not os.path.exists(db_filename_size_10M): _write_vectors_to_file(vectors[:10*10**6], db_filename_size_10M)
db_filename_size_1M = 'saved_db_1M.dat'
if not os.path.exists(db_filename_size_1M): _write_vectors_to_file(vectors[:1*10**6], db_filename_size_1M)

# %% [markdown]
# Code to generate the queries that will be used to evaluate the questions.
#
# Note: QUERY_SEED_NUMBER will be changed at submission day

# %%
needed_top_k = 10000
rng = np.random.default_rng(QUERY_SEED_NUMBER)
query1 = rng.random((1, 70), dtype=np.float32)
query2 = rng.random((1, 70), dtype=np.float32)
query3 = rng.random((1, 70), dtype=np.float32)
query_dummy = rng.random((1, 70), dtype=np.float32)

actual_sorted_ids_20m_q1 = np.argsort(vectors.dot(query1.T).T / (np.linalg.norm(vectors, axis=1) * np.linalg.norm(query1)), axis= 1).squeeze().tolist()[::-1][:needed_top_k]
gc.collect()
actual_sorted_ids_20m_q2 = np.argsort(vectors.dot(query2.T).T / (np.linalg.norm(vectors, axis=1) * np.linalg.norm(query2)), axis= 1).squeeze().tolist()[::-1][:needed_top_k]
gc.collect()
actual_sorted_ids_20m_q3 = np.argsort(vectors.dot(query3.T).T / (np.linalg.norm(vectors, axis=1) * np.linalg.norm(query3)), axis= 1).squeeze().tolist()[::-1][:needed_top_k]
gc.collect()

queries = [query1, query2, query3]
actual_sorted_ids_20m = [actual_sorted_ids_20m_q1, actual_sorted_ids_20m_q2, actual_sorted_ids_20m_q3]

# %%
# No more need to the actual vectors so delete it
del vectors
gc.collect()
# Out:
# 0

# %% [markdown]
# This code to actually run the class you have been implemented. The `VecDB` class should take the database path, and index path that you provided.<br>
# Note at the submission I'll not run the insert records. <br>
# The query istelf will be changed at submissions day but not the DB

# %%
results = []
to_print_arr = []

# %%
print("Team Number", TEAM_NUMBER)
database_info = {
    "1M": {
        "database_file_path": db_filename_size_1M,
        "index_file_path": PATH_DB_1M,
        "size": 10**6
    },
    "10M": {
        "database_file_path": db_filename_size_10M,
        "index_file_path": PATH_DB_10M,
        "size": 10 * 10**6
    },
    "15M": {
        "database_file_path": db_filename_size_15M,
        "index_file_path": PATH_DB_15M,
        "size": 15 * 10**6
    },
    "20M": {
        "database_file_path": db_filename_size_20M,
        "index_file_path": PATH_DB_20M,
        "size": 20 * 10**6
    }
}

for db_name, info in database_info.items():
    db = VecDB(database_file_path = info["database_file_path"], index_file_path = info["index_file_path"], new_db = False)
    actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, info["size"])
    # Make a dummy run query to make everything fresh and loaded (wrap up)
    res = run_queries(db, query_dummy, 5, actual_ids, 1)
    # actual runs to evaluate
    res, mem = memory_usage_run_queries((db, queries, 5, actual_ids, 3))
    eval = evaluate_result(res)
    to_print = f"{db_name}\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
    print(to_print)
    to_print_arr.append(to_print)
    del db
    del actual_ids
    del res
    del mem
    del eval
    gc.collect()
# Out:
# Team Number 14
# 1M	score	-15.0	time	0.71	RAM	6.44 MB
# 10M	score	-24.0	time	3.80	RAM	8.31 MB
# 15M	score	-30.333333333333332	time	5.09	RAM	7.59 MB
# 20M	score	-38.666666666666664	time	5.80	RAM	8.42 MB

# %%
print("Team Number", TEAM_NUMBER)
print("\n".join(to_print_arr))
# Out:
# Team Number 14
# 1M	score	-15.0	time	0.71	RAM	6.44 MB
# 10M	score	-24.0	time	3.80	RAM	8.31 MB
# 15M	score	-30.333333333333332	time	5.09	RAM	7.59 MB
# 20M	score	-38.666666666666664	time	5.80	RAM	8.42 MB
